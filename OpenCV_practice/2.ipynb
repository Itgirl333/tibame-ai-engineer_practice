# %%
import cv2
from google.colab.patches import cv2_imshow

img_raw = cv2.imread('h2.png')
img_red = img_raw[:,:,2]
img = cv2.subtract(img_red, 254)
img = cv2.multiply(img, 255)
img = cv2.absdiff(img, 255)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1087x612 at 0x7F8D9D256B50>
